# %% [markdown]
# <a href="https://colab.research.google.com/github/Huberthbt/Lekcja1/blob/main/Zadanie_domowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

Powietrze = ["Azot-N2", "tlen-O2", "gazy szlachetne-Ar,CO2" ]
percentage = [78,21,1 ]

plt.pie(percentage, labels=Powietrze)
plt.show()
